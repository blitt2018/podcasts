# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
df = pd.read_csv("/shared/3/projects/benlitterer/podcastData/processed/beforeFloydMonth/beforeFMonth.tsv")
# Out:
# <ipython-input-2-aeff8c944c94>:1: DtypeWarning: Columns (7,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/shared/3/projects/benlitterer/podcastData/processed/beforeFloydMonth/beforeFMonth.tsv")

# %%
df.sample(10)
# Out:
#         Unnamed: 0                                             rssUrl  \
# 20709      6700454            https://anchor.fm/s/c26a690/podcast/rss
# 43631     12996793          https://dynamicduotraining.libsyn.com/rss
# 123456    39402133               https://thedryeyeshow.libsyn.com/rss
# 114151    34753387  https://www.spreaker.com/show/1381273/episodes...
# 47752     14214217                  https://markcostes.libsyn.com/rss
# 92937     27490249           https://anchor.fm/s/200d508c/podcast/rss
# 90909     26947600                    https://feeds.megaphone.fm/npds
# 66390     20011704           https://anchor.fm/s/1ffd5ee8/podcast/rss
# 39631     11952710  https://feeds.soundcloud.com/users/soundcloud:...
# 25566      8177919           https://anchor.fm/s/17817330/podcast/rss
#
#                                                   epTitle  \
# 20709                  Malyk’s World Of Sports  (Trailer)
# 43631   Pro Tips to Live a Dynamic Lifestyle Series Ep...
# 123456  Lipiflow for Blepharitis, Dry Eye, and MGD Tre...
# 114151                   You Have to Get Lost To Be found
# 47752                901: Can You Still Profit with PPOs?
# 92937                                               Fhijg
# 90909       What's it like to get a call from space (5/6)
# 66390                            Just Let It Go (Trailer)
# 39631                        The Simpsons With Ryan Clark
# 25566            Contemporary Issues That Matter The Most
#
#                                             epDescription  duration  \
# 20709   --- Send in a voice message: https://podcaster...  00:00:46
# 43631   <p>Episode #13 with Jacquelyn Umof on our New ...     20:58
# 123456  <p>🔴 We just had a great interview with Dr. Ch...     49:02
# 114151  So often we find ourselves in a 'mid-life cris...      2954
# 47752   <p>Ever been frustrated with insurance compani...  01:13:15
# 92937                                             Ghjbbhj  00:00:04
# 90909   Today's word of the day is 'Major Tom' as in T...      2903
# 66390                                                 NaN  00:00:50
# 39631   The boys are back in town! And now livestreami...  00:57:47
# 25566   Teaching learning During COVID-19 phase?--- Se...  00:05:25
#
#                                 pubDate copyright itunes:type  \
# 20709     Tue, 05 May 2020 22:29:04 GMT       NaN         NaN
# 43631   Mon, 04 May 2020 13:47:10 +0000       NaN         NaN
# 123456  Wed, 06 May 2020 09:00:00 +0000       NaN         NaN
# 114151  Thu, 07 May 2020 01:32:04 +0000       NaN         NaN
# 47752   Mon, 04 May 2020 10:00:00 +0000       NaN         NaN
# 92937     Thu, 07 May 2020 06:03:30 GMT       NaN         NaN
# 90909   Wed, 06 May 2020 18:12:45 -0000       NaN         NaN
# 66390     Wed, 06 May 2020 20:34:39 GMT       NaN         NaN
# 39631   Thu, 07 May 2020 17:29:20 +0000       NaN         NaN
# 25566     Thu, 07 May 2020 16:31:46 GMT       NaN         NaN
#
#         itunes:complete                                       guid  ...  \
# 20709               NaN       80c16d07-08e6-4d97-ac38-af79beeeb278  ...
# 43631               NaN       bc53ef24-839c-47c3-905a-b3a04c1b4c7f  ...
# 123456              NaN       81f836cc-47ff-44eb-a568-8243b72562d6  ...
# 114151              NaN  https://api.spreaker.com/episode/26856083  ...
# 47752               NaN       bec804af-e9d2-4460-9d31-964208a3c513  ...
# 92937               NaN       84163446-a3a4-4168-9159-8147dc2ae51f  ...
# 90909               NaN       028ed53a-212f-11ea-9efa-87899b9003c3  ...
# 66390               NaN       72e5fda4-2bfa-4233-9fc5-154a345e7707  ...
# 39631               NaN       tag:soundcloud,2010:tracks/815664859  ...
# 25566               NaN       5753f15e-0d64-4be2-9025-7c3cea2da382  ...
#
#        category6 category7  category8 category9  category10  \
# 20709        NaN       NaN        NaN       NaN         NaN
# 43631        NaN       NaN        NaN       NaN         NaN
# 123456       NaN       NaN        NaN       NaN         NaN
# 114151       NaN       NaN        NaN       NaN         NaN
# 47752        NaN       NaN        NaN       NaN         NaN
# 92937        NaN       NaN        NaN       NaN         NaN
# 90909        NaN       NaN        NaN       NaN         NaN
# 66390        NaN       NaN        NaN       NaN         NaN
# 39631        NaN       NaN        NaN       NaN         NaN
# 25566        NaN       NaN        NaN       NaN         NaN
#
#        newestEnclosureDuration   oldestItemDatetime  \
# 20709                   1499.0  2019-06-19 18:00:22
# 43631                   1686.0  2016-05-13 16:30:00
# 123456                  2210.0  2019-07-22 09:00:00
# 114151                  3003.0  2015-03-14 05:06:05
# 47752                   3959.0  2015-02-26 16:39:34
# 92937                      4.0  2020-05-07 06:03:30
# 90909                   2921.0  2019-10-10 12:00:00
# 66390                     50.0  2020-05-06 20:34:39
# 39631                      0.0  2019-05-01 17:44:17
# 25566                    251.0  2020-05-06 16:31:46
#
#                        cleanDates  \
# 20709         2020-05-05 22:29:04
# 43631   2020-05-04 13:47:10+00:00
# 123456  2020-05-06 09:00:00+00:00
# 114151  2020-05-07 01:32:04+00:00
# 47752   2020-05-04 10:00:00+00:00
# 92937         2020-05-07 06:03:30
# 90909   2020-05-06 18:12:45+00:00
# 66390         2020-05-06 20:34:39
# 39631   2020-05-07 17:29:20+00:00
# 25566         2020-05-07 16:31:46
#
#                                          potentialOutPath  \
# 20709   /anchor.fm/2t/httpsanchor.fmsc26a690podcastpla...
# 43631   /traffic.libsyn.com/ne/httpstraffic.libsyn.com...
# 123456  /traffic.libsyn.com/er/httpstraffic.libsyn.com...
# 114151  /dts.podtrac.com/dr/httpsdts.podtrac.comredire...
# 47752   /traffic.libsyn.com/se/httpstraffic.libsyn.com...
# 92937   /anchor.fm/20/httpsanchor.fms200d508cpodcastpl...
# 90909   /www.podtrac.com/tr/httpswww.podtrac.comptsred...
# 66390   /anchor.fm/2t/httpsanchor.fms1ffd5ee8podcastpl...
# 39631   /feeds.soundcloud.com/sa/httpsfeeds.soundcloud...
# 25566   /anchor.fm/21/httpsanchor.fms17817330podcastpl...
#
#                     cleanDatesLoc
# 20709   2020-05-05 22:29:04+00:00
# 43631   2020-05-04 13:47:10+00:00
# 123456  2020-05-06 09:00:00+00:00
# 114151  2020-05-07 01:32:04+00:00
# 47752   2020-05-04 10:00:00+00:00
# 92937   2020-05-07 06:03:30+00:00
# 90909   2020-05-06 18:12:45+00:00
# 66390   2020-05-06 20:34:39+00:00
# 39631   2020-05-07 17:29:20+00:00
# 25566   2020-05-07 16:31:46+00:00
#
# [10 rows x 57 columns]

# %%
df = df[["enclosure"]]
df["processed"] = 0

# %%
df = df.rename(columns={"enclosure":"url"}).reset_index(drop=True)

# %%
df.head()
# Out:
#                                                  url  processed
# 0  https://www.samologo.com.ng/podcast-download/5...          0
# 1  https://mcdn.podbean.com/mf/web/851au9/Self_hy...          0
# 2     https://traffic.megaphone.fm/APO4624257968.mp3          0
# 3  https://anchor.fm/s/11abe148/podcast/play/1338...          0
# 4  https://pdst.fm/e/chrt.fm/track/D33B1E/traffic...          0

# %%
# Import dataframe into MySQL
import sqlalchemy
database_username = 'blitt'
database_password = 'podcasts'
database_ip       = 'curry'
database_name     = 'podcasts'

# %%
#establish connection to podcasts database
sqlEngine = sqlalchemy.create_engine('mysql+pymysql://blitt:podcasts@localhost/podcasts', pool_recycle=3600)
conn = sqlEngine.connect()

# %%
#write the dataframe to mysql table 
df.to_sql(con=conn, name='weekBeforeFloydMonth', if_exists='replace')
# Out:
# 184090

# %%
conn.close()

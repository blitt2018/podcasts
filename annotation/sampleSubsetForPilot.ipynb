# %%
import pandas as pd

# %%
df = pd.read_json("/shared/3/projects/benlitterer/podcastData/annotation/2kpodsClassification.jsonl", orient="records", lines=True)

# %%
subsetDf = df.iloc[120:240]

# %%
subsetDf.to_json("/shared/3/projects/benlitterer/podcastData/annotation/120podsClassification.jsonl", orient="records", lines=True)

# %%
subsetDf.head()
# Out:
#                                       potentialOutPath  \
# 120  /anchor.fm/2t/httpsanchor.fms6b5aef4podcastpla...
# 121  /pdcn.co/mn/httpspdcn.coemcdn.podbean.commfweb...
# 122  /mcdn.podbean.com/_e/httpsmcdn.podbean.commfwe...
# 123  /anchor.fm/23/httpsanchor.fms10a2a41cpodcastpl...
# 124  /traffic.libsyn.com/re/httpstraffic.libsyn.com...
#
#                                              descClean  \
# 120  All things AEW and WWE. Created by Alex Jawors...
# 121  Four Corners Crime Cast brings you true crime ...
# 122  A weekly podcast of conversations covering var...
# 123  Just some casual conversations with friends......
# 124  Your weekly half-hour program about environmen...
#
#                                            epDescClean  \
# 120  Alex and Justin talk about this weeks edition ...
# 121   This week we are taking a little break from h...
# 122   . Law and Liberty 's Brian Smith joins us to ...
# 123  Jazmin recounts the most dangerous game played...
# ...

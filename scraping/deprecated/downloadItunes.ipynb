# %%
from bs4 import BeautifulSoup
import requests as req
from tqdm import tqdm 
import time
import pandas as pd
import random
import matplotlib.pyplot as plt
import re

# %%
#what about the itunes search api  
IURL = "https://itunes.apple.com/search?" 
response = req.get(IURL + "term=Joe+Rogan&media=podcast")

# %%
def getRSSLinks(query): 
    IURL = "https://itunes.apple.com/search?" 
    
    qString = f'{IURL}term={query.replace(" ", "+")}&media=podcast'
    
    response = req.get(qString)
    resCode = response.status_code 
    
    try: 
        resDict = response.json()["results"]
    except JSONDecodeError: 
        print("JSONDecodeError")
        return resCode, None, None, None
    except: 
        print("Unknown Error")
        return resCode, None, None, None
    
    if len(resDict) > 0: 
        resDict = resDict[0]
        resName = resDict["collectionName"]
        creatorName = resDict["artistName"]
        
        if "feedUrl" in resDict: 
            feedUrl = resDict["feedUrl"]
            return resCode, resName, creatorName, feedUrl 
        else: 
            print("no feed URL")
            return resCode, resName, creatorName, None
    else: 
        print(f"no results for {query}")
        return resCode, None, None, None

# %%
def getMP3s(RSSLink): 
    response = req.get(RSSLink)
    print(response)

# %%
#load in a large dataframe with names of podcasts to download 
IN_PATH = "/shared/3/projects/benlitterer/podcastData/podNames/spotifySnowball50k.csv"
df = pd.read_csv(IN_PATH, index_col="Unnamed: 0")
df = df.sort_values("total_episodes", ascending=False)

# %%
def getMP3Links(rssLink): 
    #get the xml for the rss feed  
    response = req.get(rssLink)
    resCode = response.status_code
    rssText = response.text

    #pare the xml 
    rssSoup = BeautifulSoup(rssText, features="xml")
    
    epLinks = []
    items = rssSoup.find_all("item")
    
    for item in items: 
        title = item.find("title").get_text()
        podUrl = item.find("enclosure").get("url")
        desc = item.find("description").get_text()
        dur = item.find("itunes:duration").get_text()
        date = item.find("pubDate").get_text()
        transcripts = item.find_all(re.compile("transcript"))
        epLinks.append([title, podUrl, desc, dur, date, transcripts])
        
    return epLinks

# %%
midDf = df[10000:10100]

# %%
rssList = []
nameList = list(midDf.head(50)["name"])

#just focus on getting the RSS feeds here 
for name in tqdm(nameList): 
    resCode, resName, creatorName, feedUrl = getRSSLinks(name)
    
    while resCode == 404: 
        print("404 response")
        time.sleep(10)
        resCode, resName, creatorName, feedUrl = getRSSLinks(name)
    
    time.sleep(2 + random.random())
    
    rssList.append([name, resName, creatorName, feedUrl])
# Out:
#  38%|███▊      | 19/50 [00:48<01:19,  2.55s/it]
# no results for Das Mädchen im roten Mantel
#  52%|█████▏    | 26/50 [01:05<00:57,  2.39s/it]
# no results for Ava Butler Box Set
#  80%|████████  | 40/50 [01:41<00:26,  2.65s/it]
# no results for The Nightblade Epic Volume One: A Book of Underrealm
# 100%|██████████| 50/50 [02:10<00:00,  2.61s/it]

# %%
rssDf = pd.DataFrame(rssList, columns=["searchName", "resName", "resCreator", "resRSS"])

# %%
#start here with rssDf 
#TODO: next we want to use rss links to get our mp3s
rssDf.head(3)
# Out:
#                         searchName                          resName  \
# 0                  Southern Gothic                  Southern Gothic
# 1           Data Privacy Detective           Data Privacy Detective
# 2  The Carpool with Kelly and Lizz  The Carpool with Kelly and Lizz
#
#                                 resCreator  \
# 0                    Southern Gothic Media
# 1  Joe Dehner - Global Data Privacy Lawyer
# 2  The Car Mom LLC / tentwentytwo Projects
#
#                                               resRSS
# 0          https://feeds.megaphone.fm/ARML5182692989
# 1  https://feeds.soundcloud.com/users/soundcloud:...
# 2           https://feeds.megaphone.fm/ADV8086685731

# %%
epList = []
rssList = rssDf["resRSS"]

for feedUrl in rssList: 
    #only need to do something if there is a feed to follow 
    #could have empty result from previous step of finding RSS feeds 
    if len(feedUrl) > 0: 
        epLinks = getMP3Links(feedUrl)

        #add the pod level and episode level information 
        currList = [[resName, creatorName, feedUrl] + epLink for epLink in epLinks]
        epList += currList 
        time.sleep(random.random() + 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-289-35aad84286b9> in <module>
#       6     #could have empty result from previous step of finding RSS feeds
#       7     if len(feedUrl) > 0:
# ----> 8         epLinks = getMP3Links(feedUrl)
#       9
#      10         #add the pod level and episode level information
#
# <ipython-input-260-6741a5e39943> in getMP3Links(rssLink)
#      14         title = item.find("title").get_text()
#      15         podUrl = item.find("enclosure").get("url")
# ---> 16         desc = item.find("description").get_text()
#      17         dur = item.find("itunes:duration").get_text()
#      18         date = item.find("pubDate").get_text()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
podDf = pd.DataFrame(epList, columns=["name", "creator", "feedUrl", "title", "podUrl", "description", "duration", "date", "transcriptUrl"])

# %%
podDf["transLen"] = podDf["transcriptUrl"].apply(len)

# %%
podDf
# Out:
#                         name                creator  \
# 0            Southern Gothic  Southern Gothic Media
# 1            Southern Gothic  Southern Gothic Media
# 2            Southern Gothic  Southern Gothic Media
# 3            Southern Gothic  Southern Gothic Media
# 4            Southern Gothic  Southern Gothic Media
# ...                      ...                    ...
# 2345  Shawn1113 Podcast Show              Shawn1113
# 2346  Shawn1113 Podcast Show              Shawn1113
# 2347  Shawn1113 Podcast Show              Shawn1113
# 2348  Shawn1113 Podcast Show              Shawn1113
# 2349  Shawn1113 Podcast Show              Shawn1113
#
#                                         feedUrl  \
# 0     https://feeds.megaphone.fm/ARML5182692989
# 1     https://feeds.megaphone.fm/ARML5182692989
# 2     https://feeds.megaphone.fm/ARML5182692989
# 3     https://feeds.megaphone.fm/ARML5182692989
# 4     https://feeds.megaphone.fm/ARML5182692989
# ...                                         ...
# 2345   https://anchor.fm/s/239d4d4c/podcast/rss
# 2346   https://anchor.fm/s/239d4d4c/podcast/rss
# 2347   https://anchor.fm/s/239d4d4c/podcast/rss
# 2348   https://anchor.fm/s/239d4d4c/podcast/rss
# 2349   https://anchor.fm/s/239d4d4c/podcast/rss
#
#                                           title  \
# 0            The Unsolved Murder of Ethel Allen
# 1       Tuberculosis in Mammoth Cave | Minisode
# 2                          Tragedy in Sand Cave
# 3     Kathryn Tucker Windham Museum | Interview
# 4                        The Boyington Oak Tree
# ...                                         ...
# 2345            Shawn1113 Sports Show Episode 3
# 2346            Shawn1113 Sports Show Episode 3
# 2347           Shawn1113 Sports Show(Episode 2)
# 2348                      Shawn1113 Sports Show
# 2349          Shawn1113 Sports Show (Episode 1)
#
#                                                  podUrl  \
# 0     https://www.podtrac.com/pts/redirect.mp3/chrt....
# 1     https://www.podtrac.com/pts/redirect.mp3/chrt....
# 2     https://www.podtrac.com/pts/redirect.mp3/chrt....
# 3     https://www.podtrac.com/pts/redirect.mp3/chrt....
# 4     https://www.podtrac.com/pts/redirect.mp3/chrt....
# ...                                                 ...
# 2345  https://anchor.fm/s/239d4d4c/podcast/play/1516...
# 2346  https://anchor.fm/s/239d4d4c/podcast/play/1516...
# 2347  https://anchor.fm/s/239d4d4c/podcast/play/1469...
# 2348  https://anchor.fm/s/239d4d4c/podcast/play/1438...
# 2349  https://anchor.fm/s/239d4d4c/podcast/play/1438...
#
#                                             description  duration  \
# 0     Ethel Allen was last seen alive at Jack’s Tave...      1592
# 1     Last week we returned to the Mammoth Cave Nati...       614
# 2     In 1925, cave explorer Floyd Collins discovere...      2288
# 3     Kathryn Tucker Windham was an American storyte...      2297
# 4     A beautiful oak tree stands by the Church Stre...      1673
# ...                                                 ...       ...
# 2345  <p>In the midst of uncertain times in 2020 the...  00:12:49
# 2346  <p>In the midst of uncertain times in 2020 the...  00:12:39
# 2347  <p>Talking briefly about the slow but sure tri...  00:05:04
# 2348  Sports In General\n\n--- \n\nSend in a voice m...  00:07:38
# 2349  Sports in general and NFL analysis.\n\n--- \n\...  00:07:38
#
#                                  date transcriptUrl  transLen
# 0     Mon, 14 Aug 2023 05:03:00 -0000            []         0
# 1     Thu, 10 Aug 2023 05:03:00 -0000            []         0
# 2     Mon, 31 Jul 2023 05:03:00 -0000            []         0
# 3     Mon, 24 Jul 2023 05:03:00 -0000            []         0
# 4     Mon, 17 Jul 2023 05:03:00 -0000            []         0
# ...                               ...           ...       ...
# 2345    Sun, 14 Jun 2020 13:03:27 GMT            []         0
# 2346    Sun, 14 Jun 2020 12:57:59 GMT            []         0
# 2347    Wed, 03 Jun 2020 16:07:54 GMT            []         0
# 2348    Wed, 27 May 2020 22:25:59 GMT            []         0
# 2349    Wed, 27 May 2020 22:01:05 GMT            []         0
#
# [2350 rows x 10 columns]

# %%
dups = podDf[podDf.duplicated(subset=["podUrl"])].reset_index()

# %%
df.head()
# Out:
#                       searchQuery                                   name  \
# 13428             The Ryback Show                          THE HUGE SHOW
# 49349  The Steve and Kyle Podcast  Best of The Steve Harvey Morning Show
# 27733        The Ben Shapiro Show                    The Ben Maller Show
# 58082       Based on a True Story        JAM Nation with Jonesy & Amanda
# 30490              2 B's in a Pod                     Brooke and Jeffrey
#
#        type  languages                                        description  \
# 13428  show  ['en-US']  Live across Michigan every weekday, The Huge S...
# 49349  show  ['en-US']      Highlights from The Steve Harvey Morning Show
# 27733  show  ['en-US']  When the moon comes out, Ben Maller emerges wi...
# 58082  show     ['en']  Based On A True Story. JAM Nation captures the...
# 30490  show  ['en-US']  Brooke & Jeffrey In The Morning official podca...
#
#        is_externally_hosted  total_episodes
# 13428                 False           10944
# 49349                 False            8360
# 27733                 False            6238
# 58082                 False            5973
# 30490                 False            5898

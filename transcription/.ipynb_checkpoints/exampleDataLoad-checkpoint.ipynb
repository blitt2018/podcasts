# %%
import pandas as pd

# %%
df = pd.read_csv("/shared/3/projects/benlitterer/podcastData/analysis/allEpisodes.csv", lineterminator='\n')
# Out:
# <ipython-input-15-443751329637>:1: DtypeWarning: Columns (15,16,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/shared/3/projects/benlitterer/podcastData/analysis/allEpisodes.csv", lineterminator='\n')

# %%
df.tail()
# Out:
#         Unnamed: 0                         queryName  \
# 399995      408860  Stories with Brisco and Bradshaw
# 399996      408861  Stories with Brisco and Bradshaw
# 399997      408862  Stories with Brisco and Bradshaw
# 399998      408863  Stories with Brisco and Bradshaw
# 399999      408864  Stories with Brisco and Bradshaw
#
#                                    title  \
# 399995  Stories with Brisco and Bradshaw
# 399996  Stories with Brisco and Bradshaw
# 399997  Stories with Brisco and Bradshaw
# 399998  Stories with Brisco and Bradshaw
# 399999  Stories with Brisco and Bradshaw
#
#                                              url  \
# 399995  https://feeds.megaphone.fm/PHL2008380479
# 399996  https://feeds.megaphone.fm/PHL2008380479
# 399997  https://feeds.megaphone.fm/PHL2008380479
# 399998  https://feeds.megaphone.fm/PHL2008380479
# 399999  https://feeds.megaphone.fm/PHL2008380479
#
#                                      originalUrl  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'queryName', 'title', 'url', 'originalUrl', 'description',
#        'author', 'language', 'categories', 'explicit_x', 'episodeCount',
#        'epTitle', 'epDescription', 'duration', 'pubDate', 'copyright', 'type',
#        'complete', 'guid', 'explicit_y', 'mp3Url', 'image', 'transDict'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                           queryName  \
# 0           0  Unmasking the Abuser - The Podcast
# 1           1  Unmasking the Abuser - The Podcast
# 2           2  Unmasking the Abuser - The Podcast
# 3           3  Unmasking the Abuser - The Podcast
# 4           4  Unmasking the Abuser - The Podcast
#
#                                 title  \
# 0  Unmasking the Abuser - The Podcast
# 1  Unmasking the Abuser - The Podcast
# 2  Unmasking the Abuser - The Podcast
# 3  Unmasking the Abuser - The Podcast
# 4  Unmasking the Abuser - The Podcast
#
#                                        url  \
# 0  https://feeds.buzzsprout.com/985186.rss
# 1  https://feeds.buzzsprout.com/985186.rss
# 2  https://feeds.buzzsprout.com/985186.rss
# 3  https://feeds.buzzsprout.com/985186.rss
# 4  https://feeds.buzzsprout.com/985186.rss
#
#                                originalUrl  \
# 0  https://feeds.buzzsprout.com/985186.rss
# 1  https://feeds.buzzsprout.com/985186.rss
# ...

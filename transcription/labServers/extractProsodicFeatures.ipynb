# %%
import os
import time

import numpy as np
import pandas as pd
import sys 

import audb
import audiofile
import opensmile

# %%
#IN_PATH = sys.argv[1]
IN_PATH = "/shared/3/projects/benlitterer/podcastData/mp3s/testRound/11678693-episode-28-about-abusers-examining-change-part-1.wav"
#OUT_PATH = sys.argv[2]
OUT_PATH = "/shared/3/projects/benlitterer/podcastData/transcripts/premadeTransTranscripts/11678693-episode-28-about-abusers-examining-change-part-1.wav"

# %%
signal, sampling_rate = audiofile.read(
    IN_PATH,
    always_2d=True,
)

# %%
#note increasing num_workers doesn't seem to help much here 
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors, 
    num_workers=2, 
    multiprocessing=True
)

# %%
oldTime = time.time()
df = smile.process_signal(
    signal,
    sampling_rate
)
df.to_csv(OUT_PATH.split(".")[0] + "LowLevel.csv")
print(f"{time.time() - oldTime}")
# Out:
# 308.7304174900055

# %%
(38*60) + 26
# Out:
# 2306

# %%
2306 / 308
# Out:
# 7.487012987012987

# %%
df.tail()
# Out:
#                                                Loudness_sma3  alphaRatio_sma3  \
# start                  end
# 0 days 00:38:26.330000 0 days 00:38:26.350000       0.258452        -7.897347
# 0 days 00:38:26.340000 0 days 00:38:26.360000       0.252282        -4.292120
# 0 days 00:38:26.350000 0 days 00:38:26.370000       0.242032        -1.265121
# 0 days 00:38:26.360000 0 days 00:38:26.380000       0.204394        -0.636888
# 0 days 00:38:26.370000 0 days 00:38:26.420250       0.170768         0.485056
#
#                                                hammarbergIndex_sma3  \
# start                  end
# 0 days 00:38:26.330000 0 days 00:38:26.350000              8.481428
# 0 days 00:38:26.340000 0 days 00:38:26.360000              8.031472
# 0 days 00:38:26.350000 0 days 00:38:26.370000              8.724933
# 0 days 00:38:26.360000 0 days 00:38:26.380000              8.570107
# 0 days 00:38:26.370000 0 days 00:38:26.420250              7.905243
#
# ...

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.Functionals,
    num_workers=2, 
    multiprocessing=True
)
# Out:
# 0.7210252285003662

# %%
oldTime = time.time()
df = smile.process_signal(
    signal,
    sampling_rate
)
df.to_csv(OUT_PATH.split(".")[0] + "Functionals.csv")
print(f"{time.time() - oldTime}")
# Out:
# 54.98918628692627

# %%
#total time for 2306 seconds was 45 + 308 
print(f"speedup of {2306 / (45 + 308)}")
# Out:
# speedup of 6.53257790368272
